# %%
import glob 
import re
import os
import random
import sys
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from Mecab_func import*
from collections import Counter

#下村➡Old 1
#ツムラ➡New 2

# %%
#議員の名前リストを呼び出す関数
Save_name_list=[re.sub('(.*)_','',path) for path in glob.glob(r'C:\Users\icech\Desktop\share\Lab\2018_07_04\Docments\New_yato\new_text/*.txt')]
Save_name_list2=[re.sub('(.*)_','',path) for path in glob.glob(r'C:\Users\icech\Desktop\share\Lab\2018_07_04\Docments\Old_yato\old_text/*.txt')]

print(Save_name_list)
print(Save_name_list2)
# Out:
# ['津村啓介.txt', '前原誠司.txt', '階猛.txt', '辻元清美.txt', '細野豪志.txt', '山井和則.txt', '宮崎岳志.txt', '本村賢太郎.txt', '岸本周平.txt', '井出庸生.txt', '馬淵澄夫.txt', '石関貴史.txt', '西村智奈美.txt', '松野頼久.txt', '初鹿明博.txt', '阿部知子.txt', '岡本充功.txt', '小山展弘.txt', '渡辺周.txt', '逢坂誠二.txt', '青柳陽一郎.txt', '落合貴之.txt', '小熊慎司.txt', '長妻昭.txt', '大串博志.txt', '岡田克也.txt', '篠原孝.txt', '古川元久.txt']
# ['下村博文.txt', '菅原一秀.txt', '野田毅.txt', '加藤紘一.txt', '町村信孝.txt', '小里泰弘.txt', '富田茂之.txt', '金子一義.txt', '菅義偉.txt', '田村憲久.txt', '谷川弥一.txt', '谷畑孝.txt', '山本幸三.txt', '塩崎恭久.txt', '武部勤.txt', '金田勝年.txt', '遠山清彦.txt', '小泉進次郎.txt', '齋藤健.txt', '馳浩.txt', '赤澤亮正.txt', '伊東良孝.txt', '橘慶一郎.txt', '高木陽介.txt', '東順治.txt', '小野寺五典.txt', '小池百合子.txt', '佐田玄一郎.txt']

# %%
word_list=""
#最大エントロピー法に渡す形に成型する。
def Output_matsubi_BoWList(write_file,mecab_file):

    word=""
    copus_unique=[]
    for morphemes in make_lines2(mecab_file):
#形態素の数だけ取得し、コーパスに加えている
#         if len(morphemes)>=5:
#             copus.append(morphemes[-5]+morphemes[-4]+morphemes[-3]+morphemes[-2])
        if len(morphemes)>=4:
            copus.append(morphemes[-4]+morphemes[-3]+morphemes[-2])
        elif len(morphemes)>=3:
            copus.append(morphemes[-3]+morphemes[-2])
        elif len(morphemes)>=2:
            copus.append(morphemes[-2])
#リストの要素を取り出し、一つの文字列にしている。
    copus_unique=sorted(set(copus),key=copus.index)
    word=' '.join(copus_unique)
    global word_list
    word_list+=word
    word_list+='\n'
    
    with open('category2s_3matubi.txt',mode='w',newline="\n") as out_file:
        out_file.write(word_list)
    return word_list      

Mecab_path_list2=glob.glob(r'C:\Users\icech\Desktop\share\Lab\2018_07_04\Docments\New_yato\Matubi/*.txt')
# print(Mecab_path_list2)

#↑ここをNewと書き換える 
copus=[]
for i,(path,f2) in enumerate(zip(Mecab_path_list2,Save_name_list)):
    ftitle2,fext2=os.path.splitext(f2)
#     print(path)    　　#↓ここを２と書き換える
    copus.append('category2@none@{}@none@none@none@none'.format(ftitle2))
    Output_matsubi_BoWList('{}_fixed_new_matubi.txt'.format(i),'{}.mecab'.format(path))
#     docs3.append(Output_matsubi_BoWList('{}_fixed_new_matubi.txt'.format(i),'{}.mecab'.format(path)))
    copus=[]
print(word_list)
# Out:
# c:\users\icech\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: generator 'make_lines2' raised StopIteration
#   import sys
# category2@none@津村啓介@none@none@none@none の津村啓介です いたしました と思います でございます ております れました まいりました もあります であります 来年の四月 満五年 でしょうか いただきました ていただきます している ことになる お答えください もございます ていただきたい ています ませんか はないか ありがとうございます に思います いるんです がございます そして二つ目 は思います かどうか ありません ないんです 強おります 置いている の最高裁判例 では数百人 よろしいのか んだと いるわけです できるんです わけですよ はならないじゃないですか 話しましょう たいテーマです してください 終わります
# ...
