# %%
import MeCab
from collections import Counter
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties
import urllib3
import pandas as pd
import xlsxwriter
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import glob
from Mecab_func import *
import re

# %%
def new_mecab(fname,fname_parsed):
    morphemes=[]
    with open(fname,errors='ignore',encoding='utf-8_sig') as data_file, \
            open(fname_parsed, mode='w',errors='ignore') as out_file:
                #空白文字を削除する
                text_data=data_file.read()
                text_data=re.sub('.+　','',text_data)
                #改行で区切る
                text_data=re.sub('\n','',text_data)
                #句点で区切り、最後の要素を抜き取る
                text_data=text_data.split('。')
                for i,text in enumerate(text_data):
                    #読点以前を削除する
                    text=text.split('、')
                    #なぜか先頭に空白文字が入るので取り除く↓。
                    text[0]=text[0].lstrip()
#                     print(text[0])
#                     print('======tex↑=======--')    
#                     print(i)
#                     print(text)
#                     print('======text↑=======--')
#                     print(text[-1])
#                     print('======text[-1]↑=======--')
#                     print()
                    #読点以降のみが集まる↓
                    morphemes.append(text[-1])
#                 print(morphemes)    
#                     mecab = MeCab.Tagger(r'-d C:\Users\icech\mecab-ipadic-neologd\build\mecab-ipadic-2.7.0-20070801-neologd-20180625')
#                     mecab_data=mecab.parse(text[-1])
#                     print(mecab_data)
                abc=[]
                for morpheme in morphemes:
                    mecab = MeCab.Tagger(r'-d C:\Users\icech\mecab-ipadic-neologd\build\mecab-ipadic-2.7.0-20070801-neologd-20180625')
                    mecab_data=mecab.parse(morpheme)
                    cols=mecab_data.split('\t')
                    abc.append(cols[0])
#                     if(len(cols)<2):
#                         raise StopIteration
                    print(cols)
                print('abc↓')    
                print(abc)
# #                 mecab_data= re.sub('　.+.','',mecab_data)
#                 print(len(mecab_data))
#                 print(mecab_data)
#                 mecab_data=mecab_data.split('\n')
            
#     ----------------------------------------
#     for line in mecab_data:
#         cols = line.split('\t')
#         print(cols[0])
#         if(len(cols) < 2):
#             raise StopIteration
#         morphemes.append(cols[0])
#         if cols[0]=='。':
#             print(morphemes)
#             yield morphemes
#             morphemes = []


# #         print(mecab_data)
                    
                
def make_lines2(fname_parsed):#ジェネレーター
    with open(fname_parsed) as file_parsed:       

        morphemes = []
   
        for line in file_parsed:          
            cols = line.split('\t')
            if(len(cols) < 2):
                raise StopIteration     
            
            res_cols = cols[1].split(',')

    
            # 品詞細分類1が'句点'なら文の終わりと判定
            if res_cols[1] == '句点':

                # morphemes.append(cols[0])
                # ↑これがあると。が二つになってしまう
                yield morphemes
                # print(morphemes)
                morphemes = []

# %%
# for a in new_mecab(r'C:\Users\icech\Desktop\share\Lab\2018_07_04\Docments\Old_yato\old_text/11_谷畑孝.txt','hoge'):
#     print(a)

new_mecab(r'C:\Users\icech\Desktop\share\Lab\2018_07_04\Docments\Old_yato\old_text/11_谷畑孝.txt','hoge')
# Out:
# ['谷畑孝', '名詞,固有名詞,人名,一般,*,*,谷畑孝,タニハタタカシ,タニハタタカシ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nござい', '助動詞,*,*,*,五段・ラ行特殊,連用形,ござる,ゴザイ,ゴザイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['その', '連体詞,*,*,*,*,*,その,ソノ,ソノ\n趣旨', '名詞,一般,*,*,*,*,趣旨,シュシ,シュシ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n弁明', '名詞,サ変接続,*,*,*,*,弁明,ベンメイ,ベンメイ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nいたし', '動詞,自立,*,*,五段・サ行,連用形,いたす,イタシ,イタシ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['一言', '名詞,一般,*,*,*,*,一言,ヒトコト,ヒトコト\n申し上げ', '動詞,自立,*,*,一段,連用形,申し上げる,モウシアゲ,モーシアゲ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['ナンバーツー', '名詞,一般,*,*,*,*,*\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\n政治', '名詞,一般,*,*,*,*,政治,セイジ,セイジ\nと', '助詞,並立助詞,*,*,*,*,と,ト,ト\n金', '名詞,一般,*,*,*,*,金,キン,キン\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n重大', '名詞,形容動詞語幹,*,*,*,*,重大,ジュウダイ,ジューダイ\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n問題', '名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\nあり', '動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['予算案', '名詞,固有名詞,一般,*,*,*,予算案,ヨサンアン,ヨサンアン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n提出', '名詞,サ変接続,*,*,*,*,提出,テイシュツ,テイシュツ\nする', '動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\n資格', '名詞,一般,*,*,*,*,資格,シカク,シカク\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n全く', '名詞,一般,*,*,*,*,全区,ゼンク,ゼンク\nない', '形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n指摘', '名詞,サ変接続,*,*,*,*,指摘,シテキ,シテキ\nいたし', '動詞,非自立,*,*,五段・サ行,連用形,いたす,イタシ,イタシ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['いわゆる', '連体詞,*,*,*,*,*,いわゆる,イワユル,イワユル\n箇所', '名詞,一般,*,*,*,*,箇所,カショ,カショ\nづけ', '動詞,自立,*,*,一段,連用形,づける,ヅケ,ズケ\n漏えい', '名詞,サ変接続,*,*,*,*,漏えい,ロウエイ,ローエイ\n問題', '名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n発覚', '名詞,サ変接続,*,*,*,*,発覚,ハッカク,ハッカク\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nまし', '助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ\nた', '助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\nEOS\n']
# ['我々', '名詞,代名詞,一般,*,*,*,我々,ワレワレ,ワレワレ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\nこの', '連体詞,*,*,*,*,*,この,コノ,コノ\n問題', '名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n看過', '名詞,サ変接続,*,*,*,*,看過,カンカ,カンカ\nする', '動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\nでき', '動詞,自立,*,*,一段,未然形,できる,デキ,デキ\nない', '助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ\nという', '助詞,格助詞,連語,*,*,*,という,トイウ,トユウ\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n強く', '形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,強い,ツヨク,ツヨク\n申し上げる', '動詞,自立,*,*,一段,基本形,申し上げる,モウシアゲル,モーシアゲル\nもの', '名詞,非自立,一般,*,*,*,もの,モノ,モノ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['本予算', '名詞,固有名詞,一般,*,*,*,本予算,ホンヨサン,ホンヨサン\n案', '名詞,接尾,一般,*,*,*,案,アン,アン\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nつき', '動詞,自立,*,*,五段・カ行イ音便,連用形,つく,ツキ,ツキ\nまし', '助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\n問題点', '名詞,固有名詞,一般,*,*,*,問題点,モンダイテン,モンダイテン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n申し上げ', '動詞,自立,*,*,一段,連用形,申し上げる,モウシアゲ,モーシアゲ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['国債', '名詞,一般,*,*,*,*,国債,コクサイ,コクサイ\n新規', '名詞,一般,*,*,*,*,新規,シンキ,シンキ\n発行', '名詞,サ変接続,*,*,*,*,発行,ハッコウ,ハッコー\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n税収', '名詞,一般,*,*,*,*,税収,ゼイシュウ,ゼイシュー\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n上回る', '動詞,自立,*,*,五段・ラ行,基本形,上回る,ウワマワル,ウワマワル\n重大', '名詞,形容動詞語幹,*,*,*,*,重大,ジュウダイ,ジューダイ\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n歳入', '名詞,一般,*,*,*,*,歳入,サイニュウ,サイニュー\n欠陥', '名詞,一般,*,*,*,*,欠陥,ケッカン,ケッカン\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['これ', '名詞,代名詞,一般,*,*,*,これ,コレ,コレ\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\nまた', '接続詞,*,*,*,*,*,また,マタ,マタ\n大きな', '連体詞,*,*,*,*,*,大きな,オオキナ,オーキナ\n問題', '名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['マニフェスト', '名詞,一般,*,*,*,*,マニフェスト,マニフェスト,マニフェスト\n項目', '名詞,一般,*,*,*,*,項目,コウモク,コーモク\nについて', '助詞,格助詞,連語,*,*,*,について,ニツイテ,ニツイテ\nなりふり', '名詞,一般,*,*,*,*,なりふり,ナリフリ,ナリフリ\n構わ', '動詞,自立,*,*,五段・ワ行促音便,未然形,構う,カマワ,カマワ\nず', '助動詞,*,*,*,特殊・ヌ,連用ニ接続,ぬ,ズ,ズ\n予算', '名詞,一般,*,*,*,*,予算,ヨサン,ヨサン\n化', '名詞,接尾,サ変接続,*,*,*,化,カ,カ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n行っ', '動詞,自立,*,*,五段・ワ行促音便,連用タ接続,行う,オコナッ,オコナッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nい', '動詞,非自立,*,*,一段,連用形,いる,イ,イ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['経済', '名詞,一般,*,*,*,*,経済,ケイザイ,ケイザイ\n対策', '名詞,サ変接続,*,*,*,*,対策,タイサク,タイサク\nとして', '助詞,格助詞,連語,*,*,*,として,トシテ,トシテ\n全く', '名詞,一般,*,*,*,*,全区,ゼンク,ゼンク\n期待', '名詞,サ変接続,*,*,*,*,期待,キタイ,キタイ\nでき', '動詞,自立,*,*,一段,連用形,できる,デキ,デキ\nませ', '助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ\nん', '助動詞,*,*,*,不変化型,基本形,ん,ン,ン\nEOS\n']
# ['結局', '名詞,副詞可能,*,*,*,*,結局,ケッキョク,ケッキョク\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\nところ', '名詞,非自立,副詞可能,*,*,*,ところ,トコロ,トコロ\n埋蔵金', '名詞,固有名詞,一般,*,*,*,埋蔵金,マイゾウキン,マイゾーキン\n頼み', '名詞,一般,*,*,*,*,頼み,タノミ,タノミ\nという', '助詞,格助詞,連語,*,*,*,という,トイウ,トユウ\n課題', '名詞,一般,*,*,*,*,課題,カダイ,カダイ\n先送り', '名詞,サ変接続,*,*,*,*,先送り,サキオクリ,サキオクリ\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\n目', '名詞,一般,*,*,*,*,目,メ,メ\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nつき', '動詞,自立,*,*,五段・カ行イ音便,連用形,つく,ツキ,ツキ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['政府', '名詞,一般,*,*,*,*,政府,セイフ,セイフ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n財源', '名詞,一般,*,*,*,*,財源,ザイゲン,ザイゲン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nどう', '副詞,助詞類接続,*,*,*,*,どう,ドウ,ドー\n捻出', '名詞,サ変接続,*,*,*,*,捻出,ネンシュツ,ネンシュツ\nする', '動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\nの', '名詞,非自立,一般,*,*,*,の,ノ,ノ\nか', '助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ\nEOS\n']
# ['全く', '副詞,助詞類接続,*,*,*,*,全く,マッタク,マッタク\nもっ', '動詞,自立,*,*,五段・タ行,連用タ接続,もつ,モッ,モッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\n無責任', '名詞,形容動詞語幹,*,*,*,*,無責任,ムセキニン,ムセキニン\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['明確', '名詞,形容動詞語幹,*,*,*,*,明確,メイカク,メイカク\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\nマニフェスト', '名詞,一般,*,*,*,*,マニフェスト,マニフェスト,マニフェスト\n違反', '名詞,サ変接続,*,*,*,*,違反,イハン,イハン\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['到底', '副詞,一般,*,*,*,*,到底,トウテイ,トーテイ\n受け入れる', '動詞,自立,*,*,一段,基本形,受け入れる,ウケイレル,ウケイレル\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\nでき', '動詞,自立,*,*,一段,連用形,できる,デキ,デキ\nませ', '助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ\nん', '助動詞,*,*,*,不変化型,基本形,ん,ン,ン\nEOS\n']
# ['以下', '名詞,非自立,副詞可能,*,*,*,以下,イカ,イカ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n点', '名詞,非自立,一般,*,*,*,点,テン,テン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n提案', '名詞,サ変接続,*,*,*,*,提案,テイアン,テイアン\nいたし', '動詞,非自立,*,*,五段・サ行,連用形,いたす,イタシ,イタシ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['成長', '名詞,サ変接続,*,*,*,*,成長,セイチョウ,セイチョー\n投資', '名詞,サ変接続,*,*,*,*,投資,トウシ,トーシ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n分野', '名詞,一般,*,*,*,*,分野,ブンヤ,ブンヤ\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\n絞っ', '動詞,自立,*,*,五段・ラ行,連用タ接続,絞る,シボッ,シボッ\nた', '助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n投資', '名詞,サ変接続,*,*,*,*,投資,トウシ,トーシ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n行い', '動詞,自立,*,*,五段・ワ行促音便,連用形,行う,オコナイ,オコナイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['給食費', '名詞,固有名詞,一般,*,*,*,給食費,キュウショクヒ,キューショクヒ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n無償化', '名詞,固有名詞,一般,*,*,*,無償化,ムショウカ,ムショーカ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n実施', '名詞,サ変接続,*,*,*,*,実施,ジッシ,ジッシ\nす', '動詞,自立,*,*,サ変・スル,文語基本形,する,ス,ス\nべき', '助動詞,*,*,*,文語・ベシ,体言接続,べし,ベキ,ベキ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nある', '助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n提案', '名詞,サ変接続,*,*,*,*,提案,テイアン,テイアン\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['政策', '名詞,一般,*,*,*,*,政策,セイサク,セイサク\n効果', '名詞,一般,*,*,*,*,効果,コウカ,コーカ\nと', '助詞,並立助詞,*,*,*,*,と,ト,ト\n財源', '名詞,一般,*,*,*,*,財源,ザイゲン,ザイゲン\nにおいて', '助詞,格助詞,連語,*,*,*,において,ニオイテ,ニオイテ\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\n合理', '名詞,一般,*,*,*,*,合理,ゴウリ,ゴーリ\n的', '名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n政策', '名詞,一般,*,*,*,*,政策,セイサク,セイサク\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n提案', '名詞,サ変接続,*,*,*,*,提案,テイアン,テイアン\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['緊急', '名詞,形容動詞語幹,*,*,*,*,緊急,キンキュウ,キンキュー\n性', '名詞,接尾,一般,*,*,*,性,セイ,セイ\nの', '助詞,格助詞,一般,*,*,*,の,ノ,ノ\n高い', '形容詞,自立,*,*,形容詞・アウオ段,基本形,高い,タカイ,タカイ\n学校', '名詞,一般,*,*,*,*,学校,ガッコウ,ガッコー\n耐震化', '名詞,固有名詞,一般,*,*,*,耐震化,タイシンカ,タイシンカ\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\n直ちに', '副詞,一般,*,*,*,*,直ちに,タダチニ,タダチニ\n実施', '名詞,サ変接続,*,*,*,*,実施,ジッシ,ジッシ\nす', '動詞,自立,*,*,サ変・スル,文語基本形,する,ス,ス\nべき', '助動詞,*,*,*,文語・ベシ,体言接続,べし,ベキ,ベキ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['世代', '名詞,一般,*,*,*,*,世代,セダイ,セダイ\n間', '名詞,接尾,一般,*,*,*,間,カン,カン\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n不公平', '名詞,形容動詞語幹,*,*,*,*,不公平,フコウヘイ,フコーヘイ\n解消', '名詞,サ変接続,*,*,*,*,解消,カイショウ,カイショー\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\n結びつけ', '動詞,自立,*,*,一段,連用形,結びつける,ムスビツケ,ムスビツケ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['福祉', '名詞,一般,*,*,*,*,福祉,フクシ,フクシ\nなど', '助詞,副助詞,*,*,*,*,など,ナド,ナド\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n新た', '名詞,形容動詞語幹,*,*,*,*,新た,アラタ,アラタ\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n分野', '名詞,一般,*,*,*,*,分野,ブンヤ,ブンヤ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n積極', '名詞,形容動詞語幹,*,*,*,*,積極,セッキョク,セッキョク\n的', '名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ\nに', '助詞,副詞化,*,*,*,*,に,ニ,ニ\n開拓', '名詞,サ変接続,*,*,*,*,開拓,カイタク,カイタク\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['基盤', '名詞,一般,*,*,*,*,基盤,キバン,キバン\n整備', '名詞,サ変接続,*,*,*,*,整備,セイビ,セイビ\n関連', '名詞,サ変接続,*,*,*,*,関連,カンレン,カンレン\n予算', '名詞,一般,*,*,*,*,予算,ヨサン,ヨサン\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n十分', '名詞,形容動詞語幹,*,*,*,*,十分,ジュウブン,ジューブン\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n確保', '名詞,サ変接続,*,*,*,*,確保,カクホ,カクホ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n提案', '名詞,サ変接続,*,*,*,*,提案,テイアン,テイアン\nいたし', '動詞,非自立,*,*,五段・サ行,連用形,いたす,イタシ,イタシ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['それに', '接続詞,*,*,*,*,*,それに,ソレニ,ソレニ\n相応', '名詞,サ変接続,*,*,*,*,相応,ソウオウ,ソーオー\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nた', '助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n予算', '名詞,一般,*,*,*,*,予算,ヨサン,ヨサン\nと', '助詞,格助詞,一般,*,*,*,と,ト,ト\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['推進', '名詞,サ変接続,*,*,*,*,推進,スイシン,スイシン\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n基準', '名詞,一般,*,*,*,*,基準,キジュン,キジュン\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n不', '接頭詞,名詞接続,*,*,*,*,不,フ,フ\n明確', '名詞,形容動詞語幹,*,*,*,*,明確,メイカク,メイカク\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\n大きな', '連体詞,*,*,*,*,*,大きな,オオキナ,オーキナ\n問題', '名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ\nです', '助動詞,*,*,*,特殊・デス,基本形,です,デス,デス\nEOS\n']
# ['政策', '名詞,一般,*,*,*,*,政策,セイサク,セイサク\n効果', '名詞,一般,*,*,*,*,効果,コウカ,コーカ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n疑わ', '動詞,自立,*,*,五段・ワ行促音便,未然形,疑う,ウタガワ,ウタガワ\nざる', '助動詞,*,*,*,特殊・ヌ,体言接続,ぬ,ザル,ザル\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n得', '動詞,自立,*,*,一段,連用形,得る,エ,エ\nませ', '助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ\nん', '助動詞,*,*,*,不変化型,基本形,ん,ン,ン\nEOS\n']
# ['全く', '副詞,助詞類接続,*,*,*,*,全く,マッタク,マッタク\n見え', '動詞,自立,*,*,一段,連用形,見える,ミエ,ミエ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nき', '動詞,非自立,*,*,カ変・クル,連用形,くる,キ,キ\nませ', '助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ\nん', '助動詞,*,*,*,不変化型,基本形,ん,ン,ン\nEOS\n']
# ['国力', '名詞,一般,*,*,*,*,国力,コクリョク,コクリョク\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nつなげる', '動詞,自立,*,*,一段,基本形,つなげる,ツナゲル,ツナゲル\nという', '助詞,格助詞,連語,*,*,*,という,トイウ,トユウ\n基本', '名詞,一般,*,*,*,*,基本,キホン,キホン\n的', '名詞,接尾,形容動詞語幹,*,*,*,的,テキ,テキ\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n考え', '名詞,一般,*,*,*,*,考え,カンガエ,カンガエ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n持っ', '動詞,自立,*,*,五段・タ行,連用タ接続,持つ,モッ,モッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nい', '動詞,非自立,*,*,一段,連用形,いる,イ,イ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['よろしく', '副詞,一般,*,*,*,*,よろしく,ヨロシク,ヨロシク\nお願い', '名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n申し上げ', '動詞,自立,*,*,一段,連用形,申し上げる,モウシアゲ,モーシアゲ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['心より', '副詞,一般,*,*,*,*,心より,ココロヨリ,ココロヨリ\nお礼', '名詞,サ変接続,*,*,*,*,お礼,オレイ,オレイ\nと', '助詞,並立助詞,*,*,*,*,と,ト,ト\n感謝', '名詞,サ変接続,*,*,*,*,感謝,カンシャ,カンシャ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n申し上げ', '動詞,自立,*,*,一段,連用形,申し上げる,モウシアゲ,モーシアゲ\nたい', '助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思い', '動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['冒頭', '名詞,一般,*,*,*,*,冒頭,ボウトウ,ボートー\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nどうしても', '副詞,一般,*,*,*,*,どうしても,ドウシテモ,ドーシテモ\n聞い', '動詞,自立,*,*,五段・カ行イ音便,連用タ接続,聞く,キイ,キイ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nおか', '動詞,非自立,*,*,五段・カ行イ音便,未然形,おく,オカ,オカ\nなきゃ', '助動詞,*,*,*,特殊・ナイ,仮定縮約２,ない,ナキャ,ナキャ\nなら', '動詞,自立,*,*,五段・ラ行,未然形,なる,ナラ,ナラ\nぬ', '助動詞,*,*,*,特殊・ヌ,基本形,ぬ,ヌ,ヌ\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\nある', '動詞,自立,*,*,五段・ラ行,基本形,ある,アル,アル\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思い', '動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['予算委員会', '名詞,固有名詞,一般,*,*,*,予算委員会,ヨサンイインカイ,ヨサンイーンカイ\nで', '助詞,格助詞,一般,*,*,*,で,デ,デ\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\n政治', '名詞,一般,*,*,*,*,政治,セイジ,セイジ\nと', '助詞,並立助詞,*,*,*,*,と,ト,ト\n金', '名詞,固有名詞,人名,姓,*,*,金,キム,キム\nという', '助詞,格助詞,連語,*,*,*,という,トイウ,トユウ\n問題', '名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ\nについて', '助詞,格助詞,連語,*,*,*,について,ニツイテ,ニツイテ\n非常', '名詞,形容動詞語幹,*,*,*,*,非常,ヒジョウ,ヒジョー\nに', '助詞,副詞化,*,*,*,*,に,ニ,ニ\n大きな', '連体詞,*,*,*,*,*,大きな,オオキナ,オーキナ\n議論', '名詞,サ変接続,*,*,*,*,議論,ギロン,ギロン\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなり', '動詞,自立,*,*,五段・ラ行,連用形,なる,ナリ,ナリ\nまし', '助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ\nた', '助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\nEOS\n']
# ['こういう', '連体詞,*,*,*,*,*,こういう,コウイウ,コーユウ\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\nあり', '動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['この', '連体詞,*,*,*,*,*,この,コノ,コノ\nよう', '名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n声', '名詞,一般,*,*,*,*,声,コエ,コエ\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n聞こえ', '動詞,自立,*,*,一段,連用形,聞こえる,キコエ,キコエ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nくる', '動詞,非自立,*,*,カ変・クル,基本形,くる,クル,クル\nわけ', '名詞,非自立,一般,*,*,*,わけ,ワケ,ワケ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['確定申告', '名詞,固有名詞,一般,*,*,*,確定申告,カクテイシンコク,カクテイシンコク\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nかかわる', '動詞,自立,*,*,五段・ラ行,基本形,かかわる,カカワル,カカワル\nこの', '連体詞,*,*,*,*,*,この,コノ,コノ\n二人', '名詞,一般,*,*,*,*,二人,フタリ,フタリ\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\n御', '接頭詞,名詞接続,*,*,*,*,御,ゴ,ゴ\n意見', '名詞,サ変接続,*,*,*,*,意見,イケン,イケン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n一言', '名詞,サ変接続,*,*,*,*,一言,イチゲン,イチゲン\nお', '接頭詞,名詞接続,*,*,*,*,お,オ,オ\n伺い', '名詞,一般,*,*,*,*,伺い,ウカガイ,ウカガイ\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nたい', '助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思い', '動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['よろしくお願いします', '名詞,固有名詞,一般,*,*,*,よろしくお願いします,ヨロシクオネガイシマス,ヨロシクオネガイシマス\nEOS\n']
# ['ありがとう', '感動詞,*,*,*,*,*,ありがとう,アリガトウ,アリガトー\nござい', '助動詞,*,*,*,五段・ラ行特殊,連用形,ござる,ゴザイ,ゴザイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['そして', '接続詞,*,*,*,*,*,そして,ソシテ,ソシテ\nまた', '接続詞,*,*,*,*,*,また,マタ,マタ\n三ッ木', '名詞,固有名詞,人名,姓,*,*,三ッ木,ミツギ,ミツギ\nさん', '名詞,接尾,人名,*,*,*,さん,サン,サン\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\nお願い', '名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nたい', '助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思い', '動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['今回', '名詞,副詞可能,*,*,*,*,今回,コンカイ,コンカイ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n予算', '名詞,一般,*,*,*,*,予算,ヨサン,ヨサン\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n九', '名詞,数,*,*,*,*,九,キュウ,キュー\n十', '名詞,数,*,*,*,*,十,ジュウ,ジュー\n二', '名詞,数,*,*,*,*,二,ニ,ニ\n兆', '名詞,数,*,*,*,*,兆,チョウ,チョー\n円', '名詞,接尾,助数詞,*,*,*,円,エン,エン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n超える', '動詞,自立,*,*,一段,基本形,超える,コエル,コエル\nという', '助詞,格助詞,連語,*,*,*,という,トイウ,トユウ\n最大', '名詞,一般,*,*,*,*,最大,サイダイ,サイダイ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n予算', '名詞,一般,*,*,*,*,予算,ヨサン,ヨサン\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ', '動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ', '動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nいる', '動詞,非自立,*,*,一段,基本形,いる,イル,イル\nEOS\n']
# ['過去', '名詞,副詞可能,*,*,*,*,過去,カコ,カコ\n最大', '名詞,一般,*,*,*,*,最大,サイダイ,サイダイ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n四', '名詞,数,*,*,*,*,四,ヨン,ヨン\n十', '名詞,数,*,*,*,*,十,ジュウ,ジュー\n四', '名詞,数,*,*,*,*,四,ヨン,ヨン\n兆', '名詞,数,*,*,*,*,兆,チョウ,チョー\n円', '名詞,接尾,助数詞,*,*,*,円,エン,エン\nという', '助詞,格助詞,連語,*,*,*,という,トイウ,トユウ\n国債', '名詞,一般,*,*,*,*,国債,コクサイ,コクサイ\n発行', '名詞,サ変接続,*,*,*,*,発行,ハッコウ,ハッコー\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ', '動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ', '動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nいる', '動詞,非自立,*,*,一段,基本形,いる,イル,イル\nEOS\n']
# ['まさしく', '副詞,一般,*,*,*,*,まさしく,マサシク,マサシク\n恒久', '名詞,一般,*,*,*,*,恒久,コウキュウ,コーキュー\n政策', '名詞,一般,*,*,*,*,政策,セイサク,セイサク\nだ', '助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思う', '動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ\nん', '名詞,非自立,一般,*,*,*,ん,ン,ン\nです', '助動詞,*,*,*,特殊・デス,基本形,です,デス,デス\nEOS\n']
# ['こういう', '連体詞,*,*,*,*,*,こういう,コウイウ,コーユウ\n非常', '名詞,形容動詞語幹,*,*,*,*,非常,ヒジョウ,ヒジョー\nに', '助詞,副詞化,*,*,*,*,に,ニ,ニ\n不安定', '名詞,形容動詞語幹,*,*,*,*,不安定,フアンテイ,フアンテイ\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n予算', '名詞,一般,*,*,*,*,予算,ヨサン,ヨサン\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n組み方', '名詞,一般,*,*,*,*,組み方,クミカタ,クミカタ\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ', '動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nしまっ', '動詞,非自立,*,*,五段・ワ行促音便,連用タ接続,しまう,シマッ,シマッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nいる', '動詞,非自立,*,*,一段,基本形,いる,イル,イル\nEOS\n']
# ['この', '連体詞,*,*,*,*,*,この,コノ,コノ\nマニフェスト', '名詞,一般,*,*,*,*,マニフェスト,マニフェスト,マニフェスト\nと', '助詞,並立助詞,*,*,*,*,と,ト,ト\n予算', '名詞,一般,*,*,*,*,予算,ヨサン,ヨサン\nという', '助詞,格助詞,連語,*,*,*,という,トイウ,トユウ\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nで', '助詞,格助詞,一般,*,*,*,で,デ,デ\nどの', '連体詞,*,*,*,*,*,どの,ドノ,ドノ\nよう', '名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n硬直', '名詞,サ変接続,*,*,*,*,硬直,コウチョク,コーチョク\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nた', '助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\n予算', '名詞,一般,*,*,*,*,予算,ヨサン,ヨサン\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなっ', '動詞,自立,*,*,五段・ラ行,連用タ接続,なる,ナッ,ナッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nいく', '動詞,非自立,*,*,五段・カ行促音便,基本形,いく,イク,イク\nの', '名詞,非自立,一般,*,*,*,の,ノ,ノ\nか', '助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ\n非常', '名詞,形容動詞語幹,*,*,*,*,非常,ヒジョウ,ヒジョー\nに', '助詞,副詞化,*,*,*,*,に,ニ,ニ\n不安', '名詞,形容動詞語幹,*,*,*,*,不安,フアン,フアン\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nある', '助動詞,*,*,*,五段・ラ行アル,基本形,ある,アル,アル\nEOS\n']
# ['この', '連体詞,*,*,*,*,*,この,コノ,コノ\nよう', '名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー\nに', '助詞,副詞化,*,*,*,*,に,ニ,ニ\n私', '名詞,代名詞,一般,*,*,*,私,ワタシ,ワタシ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n思う', '動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ\nん', '名詞,非自立,一般,*,*,*,ん,ン,ン\nです', '助動詞,*,*,*,特殊・デス,基本形,です,デス,デス\nEOS\n']
# ['簡単', '名詞,形容動詞語幹,*,*,*,*,簡単,カンタン,カンタン\nに', '助詞,副詞化,*,*,*,*,に,ニ,ニ\nひとつ', '名詞,副詞可能,*,*,*,*,ひとつ,ヒトツ,ヒトツ\n意見', '名詞,サ変接続,*,*,*,*,意見,イケン,イケン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nお', '接頭詞,名詞接続,*,*,*,*,お,オ,オ\n聞き', '動詞,自立,*,*,五段・カ行イ音便,連用形,聞く,キキ,キキ\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nたい', '助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思い', '動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['非常', '名詞,形容動詞語幹,*,*,*,*,非常,ヒジョウ,ヒジョー\nに', '助詞,副詞化,*,*,*,*,に,ニ,ニ\n低い', '形容詞,自立,*,*,形容詞・アウオ段,基本形,低い,ヒクイ,ヒクイ\n負担', '名詞,サ変接続,*,*,*,*,負担,フタン,フタン\nで', '助詞,格助詞,一般,*,*,*,で,デ,デ\n中', '接頭詞,名詞接続,*,*,*,*,中,チュウ,チュー\nサービス', '名詞,サ変接続,*,*,*,*,サービス,サービス,サービス\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n行っ', '動詞,自立,*,*,五段・ワ行促音便,連用タ接続,行う,オコナッ,オコナッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nいる', '動詞,非自立,*,*,一段,基本形,いる,イル,イル\nEOS\n']
# ['ここ', '名詞,代名詞,一般,*,*,*,ここ,ココ,ココ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\nやはり', '副詞,一般,*,*,*,*,やはり,ヤハリ,ヤハリ\nしっかり', '副詞,助詞類接続,*,*,*,*,しっかり,シッカリ,シッカリ\nと', '助詞,副詞化,*,*,*,*,と,ト,ト\n議論', '名詞,サ変接続,*,*,*,*,議論,ギロン,ギロン\nし', '動詞,自立,*,*,サ変・スル,未然形,する,シ,シ\nなきゃ', '助動詞,*,*,*,特殊・ナイ,仮定縮約２,ない,ナキャ,ナキャ\nなら', '動詞,自立,*,*,五段・ラ行,未然形,なる,ナラ,ナラ\nぬ', '助動詞,*,*,*,特殊・ヌ,基本形,ぬ,ヌ,ヌ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思う', '動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ\nん', '名詞,非自立,一般,*,*,*,ん,ン,ン\nです', '助動詞,*,*,*,特殊・デス,基本形,です,デス,デス\nね', '助詞,終助詞,*,*,*,*,ね,ネ,ネ\nEOS\n']
# ['この', '連体詞,*,*,*,*,*,この,コノ,コノ\nよう', '名詞,非自立,助動詞語幹,*,*,*,よう,ヨウ,ヨー\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\n状況', '名詞,一般,*,*,*,*,状況,ジョウキョウ,ジョーキョー\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nなる', '動詞,自立,*,*,五段・ラ行,基本形,なる,ナル,ナル\nわけ', '名詞,非自立,一般,*,*,*,わけ,ワケ,ワケ\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\nん', '名詞,非自立,一般,*,*,*,ん,ン,ン\nです', '助動詞,*,*,*,特殊・デス,基本形,です,デス,デス\nね', '助詞,終助詞,*,*,*,*,ね,ネ,ネ\nEOS\n']
# ['少し', '副詞,助詞類接続,*,*,*,*,少し,スコシ,スコシ\n意見', '名詞,サ変接続,*,*,*,*,意見,イケン,イケン\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\nあり', '動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ\nまし', '助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ\nたら', '助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ\n一言', '名詞,一般,*,*,*,*,一言,ヒトコト,ヒトコト\nお願い', '名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['こういう', '連体詞,*,*,*,*,*,こういう,コウイウ,コーユウ\n話', '名詞,サ変接続,*,*,*,*,話,ハナシ,ハナシ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nよく', '副詞,一般,*,*,*,*,よく,ヨク,ヨク\n聞き', '動詞,自立,*,*,五段・カ行イ音便,連用形,聞く,キキ,キキ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['こういう', '連体詞,*,*,*,*,*,こういう,コウイウ,コーユウ\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['ここ', '名詞,代名詞,一般,*,*,*,ここ,ココ,ココ\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\nまた', '接続詞,*,*,*,*,*,また,マタ,マタ\n企業', '名詞,一般,*,*,*,*,企業,キギョウ,キギョー\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n外国', '名詞,一般,*,*,*,*,外国,ガイコク,ガイコク\nへ', '助詞,格助詞,一般,*,*,*,へ,ヘ,エ\n出', '動詞,自立,*,*,一段,連用形,出る,デ,デ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nしまう', '動詞,非自立,*,*,五段・ワ行促音便,基本形,しまう,シマウ,シマウ\nEOS\n']
# ['つくづく', '副詞,一般,*,*,*,*,つくづく,ツクヅク,ツクズク\nそう', '副詞,助詞類接続,*,*,*,*,そう,ソウ,ソー\n思う', '動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ\nん', '名詞,非自立,一般,*,*,*,ん,ン,ン\nです', '助動詞,*,*,*,特殊・デス,基本形,です,デス,デス\nね', '助詞,終助詞,*,*,*,*,ね,ネ,ネ\nEOS\n']
# ['小西', '名詞,固有名詞,人名,姓,*,*,小西,コニシ,コニシ\n先生', '名詞,一般,*,*,*,*,先生,センセイ,センセイ\nと', '助詞,並立助詞,*,*,*,*,と,ト,ト\n嶋田', '名詞,固有名詞,人名,姓,*,*,嶋田,シマダ,シマダ\nさん', '名詞,接尾,人名,*,*,*,さん,サン,サン\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nもう一度', '副詞,一般,*,*,*,*,もう一度,モウイチド,モーイチド\nお', '接頭詞,名詞接続,*,*,*,*,お,オ,オ\n聞き', '動詞,自立,*,*,五段・カ行イ音便,連用形,聞く,キキ,キキ\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nたい', '助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ\nEOS\n']
# ['嶋田', '名詞,固有名詞,人名,姓,*,*,嶋田,シマダ,シマダ\nさん', '名詞,接尾,人名,*,*,*,さん,サン,サン\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\nもう', '副詞,一般,*,*,*,*,もう,モウ,モー\n一つ', '名詞,一般,*,*,*,*,一つ,ヒトツ,ヒトツ\nEOS\n']
# ['自動車', '名詞,一般,*,*,*,*,自動車,ジドウシャ,ジドーシャ\n関係', '名詞,サ変接続,*,*,*,*,関係,カンケイ,カンケイ\nだ', '助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思い', '動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nので', '助詞,接続助詞,*,*,*,*,ので,ノデ,ノデ\nお願い', '名詞,サ変接続,*,*,*,*,お願い,オネガイ,オネガイ\nいたし', '動詞,非自立,*,*,五段・サ行,連用形,いたす,イタシ,イタシ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['小西', '名詞,固有名詞,人名,姓,*,*,小西,コニシ,コニシ\n先生', '名詞,一般,*,*,*,*,先生,センセイ,センセイ\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nEOS\n']
# ['財政再建', '名詞,固有名詞,一般,*,*,*,財政再建,ザイセイサイケン,ザイセイサイケン\nという', '助詞,格助詞,連語,*,*,*,という,トイウ,トユウ\nの', '名詞,非自立,一般,*,*,*,の,ノ,ノ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n非常', '名詞,形容動詞語幹,*,*,*,*,非常,ヒジョウ,ヒジョー\nに', '助詞,副詞化,*,*,*,*,に,ニ,ニ\n大事', '名詞,形容動詞語幹,*,*,*,*,大事,ダイジ,ダイジ\nな', '助動詞,*,*,*,特殊・ダ,体言接続,だ,ナ,ナ\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nだ', '助動詞,*,*,*,特殊・ダ,基本形,だ,ダ,ダ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思う', '動詞,自立,*,*,五段・ワ行促音便,基本形,思う,オモウ,オモウ\nん', '名詞,非自立,一般,*,*,*,ん,ン,ン\nです', '助動詞,*,*,*,特殊・デス,基本形,です,デス,デス\nね', '助詞,終助詞,*,*,*,*,ね,ネ,ネ\nEOS\n']
# ['結局', '名詞,副詞可能,*,*,*,*,結局,ケッキョク,ケッキョク\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\nところ', '名詞,非自立,副詞可能,*,*,*,ところ,トコロ,トコロ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n税', '名詞,一般,*,*,*,*,税,ゼイ,ゼイ\n収入', '名詞,一般,*,*,*,*,収入,シュウニュウ,シューニュー\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\nどう', '副詞,助詞類接続,*,*,*,*,どう,ドウ,ドー\nか', '助詞,副助詞／並立助詞／終助詞,*,*,*,*,か,カ,カ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\nEOS\n']
# ['あり', '動詞,自立,*,*,五段・ラ行,連用形,ある,アリ,アリ\nまし', '助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ\nたら', '助動詞,*,*,*,特殊・タ,仮定形,た,タラ,タラ\nお', '接頭詞,名詞接続,*,*,*,*,お,オ,オ\n聞き', '動詞,自立,*,*,五段・カ行イ音便,連用形,聞く,キキ,キキ\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\n終わり', '動詞,自立,*,*,五段・ラ行,連用形,終わる,オワリ,オワリ\nたい', '助動詞,*,*,*,特殊・タイ,基本形,たい,タイ,タイ\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n思い', '動詞,自立,*,*,五段・ワ行促音便,連用形,思う,オモイ,オモイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['終わり', '動詞,自立,*,*,五段・ラ行,連用形,終わる,オワリ,オワリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['ありがとう', '感動詞,*,*,*,*,*,ありがとう,アリガトウ,アリガトー\nござい', '助動詞,*,*,*,五段・ラ行特殊,連用形,ござる,ゴザイ,ゴザイ\nまし', '助動詞,*,*,*,特殊・マス,連用形,ます,マシ,マシ\nた', '助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\nEOS\n']
# ['自由民主党', '名詞,固有名詞,組織,*,*,*,自由民主党,ジユウミンシュトウ,ジユーミンシュトー\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n谷畑孝', '名詞,固有名詞,人名,一般,*,*,谷畑孝,タニハタタカシ,タニハタタカシ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nござい', '助動詞,*,*,*,五段・ラ行特殊,連用形,ござる,ゴザイ,ゴザイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['反対', '名詞,サ変接続,*,*,*,*,反対,ハンタイ,ハンタイ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n立場', '名詞,一般,*,*,*,*,立場,タチバ,タチバ\nから', '助詞,格助詞,一般,*,*,*,から,カラ,カラ\n討論', '名詞,サ変接続,*,*,*,*,討論,トウロン,トーロン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nいたし', '動詞,自立,*,*,五段・サ行,連用形,いたす,イタシ,イタシ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['本', '接頭詞,名詞接続,*,*,*,*,本,ホン,ホン\n二次', '名詞,一般,*,*,*,*,二次,ニジ,ニジ\n補正予算', '名詞,固有名詞,一般,*,*,*,補正予算,ホセイヨサン,ホセイヨサン\nで', '助詞,格助詞,一般,*,*,*,で,デ,デ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n景気', '名詞,一般,*,*,*,*,景気,ケイキ,ケイキ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n好転', '名詞,サ変接続,*,*,*,*,好転,コウテン,コーテン\nさ', '動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ\nせる', '動詞,接尾,*,*,一段,基本形,せる,セル,セル\n経済効果', '名詞,固有名詞,一般,*,*,*,経済効果,ケイザイコウカ,ケイザイコーカ\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n乏しい', '形容詞,自立,*,*,形容詞・イ段,基本形,乏しい,トボシイ,トボシイ\nEOS\n']
# ['削減', '名詞,サ変接続,*,*,*,*,削減,サクゲン,サクゲン\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nた', '助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\nマイナス', '名詞,一般,*,*,*,*,マイナス,マイナス,マイナス\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n影響', '名詞,サ変接続,*,*,*,*,影響,エイキョウ,エイキョー\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n方', '名詞,非自立,一般,*,*,*,方,ホウ,ホー\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n大きい', '形容詞,自立,*,*,形容詞・イ段,基本形,大きい,オオキイ,オーキイ\nの', '名詞,非自立,一般,*,*,*,の,ノ,ノ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['約', '接頭詞,数接続,*,*,*,*,約,ヤク,ヤク\n五', '名詞,数,*,*,*,*,五,ゴ,ゴ\n千', '名詞,数,*,*,*,*,千,セン,セン\n億', '名詞,数,*,*,*,*,億,オク,オク\n円', '名詞,接尾,助数詞,*,*,*,円,エン,エン\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n実質', '名詞,一般,*,*,*,*,実質,ジッシツ,ジッシツ\nＧＤＰ', '名詞,一般,*,*,*,*,GDP,ジーディーピー,ジーディーピー\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n減少', '名詞,サ変接続,*,*,*,*,減少,ゲンショウ,ゲンショー\nする', '動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\n見込み', '名詞,一般,*,*,*,*,見込み,ミコミ,ミコミ\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n試算', '名詞,サ変接続,*,*,*,*,試算,シサン,シサン\nさ', '動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ\nれ', '動詞,接尾,*,*,一段,連用形,れる,レ,レ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nい', '動詞,非自立,*,*,一段,連用形,いる,イ,イ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['何ら', '副詞,一般,*,*,*,*,何ら,ナンラ,ナンラ\n経済', '名詞,一般,*,*,*,*,経済,ケイザイ,ケイザイ\n対策', '名詞,サ変接続,*,*,*,*,対策,タイサク,タイサク\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n名', '名詞,一般,*,*,*,*,名,ナ,ナ\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\n値し', '動詞,自立,*,*,サ変・−スル,未然形,値する,アタイシ,アタイシ\nませ', '助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ\nん', '助動詞,*,*,*,不変化型,基本形,ん,ン,ン\nEOS\n']
# ['緊急', '名詞,形容動詞語幹,*,*,*,*,緊急,キンキュウ,キンキュー\nと', '助詞,格助詞,引用,*,*,*,と,ト,ト\n銘打っ', '動詞,自立,*,*,五段・タ行,連用タ接続,銘打つ,メイウッ,メイウッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nい', '動詞,非自立,*,*,一段,連用形,いる,イ,イ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\n緊急', '名詞,形容動詞語幹,*,*,*,*,緊急,キンキュウ,キンキュー\n性', '名詞,接尾,一般,*,*,*,性,セイ,セイ\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n伝わっ', '動詞,自立,*,*,五段・ラ行,連用タ接続,伝わる,ツタワッ,ツタワッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nこ', '動詞,非自立,*,*,カ変・クル,未然形,くる,コ,コ\nない', '助動詞,*,*,*,特殊・ナイ,基本形,ない,ナイ,ナイ\nの', '名詞,非自立,一般,*,*,*,の,ノ,ノ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n私', '名詞,代名詞,一般,*,*,*,私,ワタシ,ワタシ\nだけ', '助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\nない', '形容詞,自立,*,*,形容詞・アウオ段,基本形,ない,ナイ,ナイ\nはず', '名詞,非自立,一般,*,*,*,はず,ハズ,ハズ\nです', '助動詞,*,*,*,特殊・デス,基本形,です,デス,デス\nEOS\n']
# ['本予算', '名詞,固有名詞,一般,*,*,*,本予算,ホンヨサン,ホンヨサン\nと', '助詞,格助詞,一般,*,*,*,と,ト,ト\n関連', '名詞,サ変接続,*,*,*,*,関連,カンレン,カンレン\nさ', '動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ\nせ', '動詞,接尾,*,*,一段,連用形,せる,セ,セ\nつつ', '助詞,接続助詞,*,*,*,*,つつ,ツツ,ツツ\n切れ目', '名詞,一般,*,*,*,*,切れ目,キレメ,キレメ\nなく', '形容詞,自立,*,*,形容詞・アウオ段,連用テ接続,ない,ナク,ナク\n実施', '名詞,サ変接続,*,*,*,*,実施,ジッシ,ジッシ\nする', '動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\nこと', '名詞,非自立,一般,*,*,*,こと,コト,コト\nこそ', '助詞,係助詞,*,*,*,*,こそ,コソ,コソ\n政策', '名詞,一般,*,*,*,*,政策,セイサク,セイサク\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n妙', '名詞,形容動詞語幹,*,*,*,*,妙,ミョウ,ミョー\nという', '助詞,格助詞,連語,*,*,*,という,トイウ,トユウ\nもの', '名詞,非自立,一般,*,*,*,もの,モノ,モノ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['あわせ', '動詞,自立,*,*,一段,連用形,あわせる,アワセ,アワセ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\n付言', '名詞,サ変接続,*,*,*,*,付言,フゲン,フゲン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\nいたし', '動詞,自立,*,*,五段・サ行,連用形,いたす,イタシ,イタシ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['また', '接続詞,*,*,*,*,*,また,マタ,マタ\n解凍', '名詞,サ変接続,*,*,*,*,解凍,カイトウ,カイトー\nし', '動詞,自立,*,*,サ変・スル,連用形,する,シ,シ\nた', '助動詞,*,*,*,特殊・タ,基本形,た,タ,タ\nだけ', '助詞,副助詞,*,*,*,*,だけ,ダケ,ダケ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['工夫', '名詞,サ変接続,*,*,*,*,工夫,クフウ,クフー\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\n欠け', '動詞,自立,*,*,一段,連用形,欠ける,カケ,カケ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nおり', '動詞,非自立,*,*,五段・ラ行,連用形,おる,オリ,オリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['約', '接頭詞,数接続,*,*,*,*,約,ヤク,ヤク\n三', '名詞,数,*,*,*,*,三,サン,サン\n兆', '名詞,数,*,*,*,*,兆,チョウ,チョー\n円', '名詞,接尾,助数詞,*,*,*,円,エン,エン\nも', '助詞,係助詞,*,*,*,*,も,モ,モ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n削減', '名詞,サ変接続,*,*,*,*,削減,サクゲン,サクゲン\n及び', '接続詞,*,*,*,*,*,及び,オヨビ,オヨビ\n政策', '名詞,一般,*,*,*,*,政策,セイサク,セイサク\n実行', '名詞,サ変接続,*,*,*,*,実行,ジッコウ,ジッコー\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n空白', '名詞,一般,*,*,*,*,空白,クウハク,クーハク\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n生ん', '動詞,自立,*,*,五段・マ行,連用タ接続,生む,ウン,ウン\nだ', '助動詞,*,*,*,特殊・タ,基本形,だ,ダ,ダ\n鳩山政権', '名詞,固有名詞,一般,*,*,*,鳩山政権,ハトヤマセイケン,ハトヤマセイケン\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n責任', '名詞,一般,*,*,*,*,責任,セキニン,セキニン\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n極めて', '副詞,一般,*,*,*,*,極めて,キワメテ,キワメテ\n重い', '形容詞,自立,*,*,形容詞・アウオ段,基本形,重い,オモイ,オモイ\nもの', '名詞,非自立,一般,*,*,*,もの,モノ,モノ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nあり', '助動詞,*,*,*,五段・ラ行アル,連用形,ある,アリ,アリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['地方自治体', '名詞,一般,*,*,*,*,地方自治体,チホウジチタイ,チホージチタイ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n歳入', '名詞,一般,*,*,*,*,歳入,サイニュウ,サイニュー\n対策', '名詞,サ変接続,*,*,*,*,対策,タイサク,タイサク\nとして', '助詞,格助詞,連語,*,*,*,として,トシテ,トシテ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n地方交付税法', '名詞,固有名詞,一般,*,*,*,地方交付税法,チホウコウフゼイホウ,チホーコーフゼイホー\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n改正', '名詞,サ変接続,*,*,*,*,改正,カイセイ,カイセイ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n反対', '名詞,サ変接続,*,*,*,*,反対,ハンタイ,ハンタイ\nする', '動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\nもの', '名詞,非自立,一般,*,*,*,もの,モノ,モノ\nで', '助動詞,*,*,*,特殊・ダ,連用形,だ,デ,デ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\nありません', '名詞,固有名詞,一般,*,*,*,有馬線,アリマセン,アリマセン\nEOS\n']
# ['政権', '名詞,一般,*,*,*,*,政権,セイケン,セイケン\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n信頼性', '名詞,固有名詞,一般,*,*,*,信頼性,シンライセイ,シンライセイ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n問題', '名詞,ナイ形容詞語幹,*,*,*,*,問題,モンダイ,モンダイ\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\nござい', '動詞,自立,*,*,五段・ラ行特殊,連用形,ござる,ゴザイ,ゴザイ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['残念', '名詞,形容動詞語幹,*,*,*,*,残念,ザンネン,ザンネン\nながら', '助詞,接続助詞,*,*,*,*,ながら,ナガラ,ナガラ\n首相', '名詞,一般,*,*,*,*,首相,シュショウ,シュショー\n御', '接頭詞,名詞接続,*,*,*,*,御,ゴ,ゴ\n本人', '名詞,一般,*,*,*,*,本人,ホンニン,ホンニン\nが', '助詞,格助詞,一般,*,*,*,が,ガ,ガ\n全く', '名詞,一般,*,*,*,*,全区,ゼンク,ゼンク\n自覚', '名詞,サ変接続,*,*,*,*,自覚,ジカク,ジカク\nさ', '動詞,自立,*,*,サ変・スル,未然レル接続,する,サ,サ\nれ', '動詞,接尾,*,*,一段,連用形,れる,レ,レ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nおり', '動詞,非自立,*,*,五段・ラ行,連用形,おる,オリ,オリ\nませ', '助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ\nん', '助動詞,*,*,*,不変化型,基本形,ん,ン,ン\nEOS\n']
# ['民主党', '名詞,固有名詞,組織,*,*,*,民主党,ミンシュトウ,ミンシュトー\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n実態', '名詞,一般,*,*,*,*,実態,ジッタイ,ジッタイ\n解明', '名詞,サ変接続,*,*,*,*,解明,カイメイ,カイメイ\nする', '動詞,自立,*,*,サ変・スル,基本形,する,スル,スル\n努力', '名詞,サ変接続,*,*,*,*,努力,ドリョク,ドリョク\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n怠っ', '動詞,自立,*,*,五段・ラ行,連用タ接続,怠る,オコタッ,オコタッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nい', '動詞,非自立,*,*,一段,連用形,いる,イ,イ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['実現', '名詞,サ変接続,*,*,*,*,実現,ジツゲン,ジツゲン\nに', '助詞,格助詞,一般,*,*,*,に,ニ,ニ\n至っ', '動詞,自立,*,*,五段・ラ行,連用タ接続,至る,イタッ,イタッ\nて', '助詞,接続助詞,*,*,*,*,て,テ,テ\nおり', '動詞,非自立,*,*,五段・ラ行,連用形,おる,オリ,オリ\nませ', '助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ\nん', '助動詞,*,*,*,不変化型,基本形,ん,ン,ン\nEOS\n']
# ['政権', '名詞,一般,*,*,*,*,政権,セイケン,セイケン\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n信頼性', '名詞,固有名詞,一般,*,*,*,信頼性,シンライセイ,シンライセイ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n欠如', '名詞,サ変接続,*,*,*,*,欠如,ケツジョ,ケツジョ\nは', '助詞,係助詞,*,*,*,*,は,ハ,ワ\n到底', '副詞,一般,*,*,*,*,到底,トウテイ,トーテイ\n容認', '名詞,サ変接続,*,*,*,*,容認,ヨウニン,ヨーニン\nでき', '動詞,自立,*,*,一段,連用形,できる,デキ,デキ\nませ', '助動詞,*,*,*,特殊・マス,未然形,ます,マセ,マセ\nん', '助動詞,*,*,*,不変化型,基本形,ん,ン,ン\nEOS\n']
# ['私', '名詞,代名詞,一般,*,*,*,私,ワタシ,ワタシ\nの', '助詞,連体化,*,*,*,*,の,ノ,ノ\n反対', '名詞,サ変接続,*,*,*,*,反対,ハンタイ,ハンタイ\n討論', '名詞,サ変接続,*,*,*,*,討論,トウロン,トーロン\nを', '助詞,格助詞,一般,*,*,*,を,ヲ,ヲ\n終わり', '動詞,自立,*,*,五段・ラ行,連用形,終わる,オワリ,オワリ\nます', '助動詞,*,*,*,特殊・マス,基本形,ます,マス,マス\nEOS\n']
# ['（', '記号,括弧開,*,*,*,*,（,（,（\n拍手', '名詞,サ変接続,*,*,*,*,拍手,ハクシュ,ハクシュ\n）', '記号,括弧閉,*,*,*,*,）,）,）\nEOS\n']
# abc↓
# ['谷畑孝', 'その', '一言', 'ナンバーツー', '予算案', 'いわゆる', '我々', '本予算', '国債', 'これ', 'マニフェスト', '経済', '結局', '政府', '全く', '明確', '到底', '以下', '成長', '給食費', '政策', '緊急', '世代', '福祉', '基盤', 'それに', '推進', '政策', '全く', '国力', 'よろしく', '心より', '冒頭', '予算委員会', 'こういう', 'この', '確定申告', 'よろしくお願いします', 'ありがとう', 'そして', '今回', '過去', 'まさしく', 'こういう', 'この', 'この', '簡単', '非常', 'ここ', 'この', '少し', 'こういう', 'こういう', 'ここ', 'つくづく', '小西', '嶋田', '自動車', '小西', '財政再建', '結局', 'あり', '終わり', 'ありがとう', '自由民主党', '反対', '本', '削減', '約', '何ら', '緊急', '本予算', 'あわせ', 'また', '工夫', '約', '地方自治体', '政権', '残念', '民主党', '実現', '政権', '私', '（']

# %%
new_list=glob.glob(r'C:\Users\icech\Desktop\share\Lab\2018_07_04\Docments\New_yato\new_text')
old_list=glob.glob(r'C:\Users\icech\Desktop\share\Lab\2018_07_04\Docments\Old_yato\old_text')

for file in new_list:
    to_mecab(file,'{}.mecab'.format(file))

for file in old_list:
    to_mecab(file,'{}.mecab'.format(file))
